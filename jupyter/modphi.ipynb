# %%
import sys
import numpy as np 
import networkx as nx
sys.path.insert(0, "../src/")
from modcalculus import *

# %%
ER = ErdosRenyi()
G = ER(10, 0.3)

# %%
G = Graph([0,2,4,5,8],[(0,2),(0,4),(4,5),(4,8)])
IG = IsomorphismClassGraph([0,2,4,5,8],[(0,2),(0,4),(4,5),(4,8)])
G.draw()

# %%
IG.draw()

# %%
G.is_isomorphic(IG)
# Out:
# True

# %%
# Out:
# False
